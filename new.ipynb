# %%
# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()

# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()

# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()

# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()

# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()

# 8. Classes and Objects
class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print(self.name + " says Woof!")

my_dog = Dog("Buddy")
my_dog.bark()
my_dog = Dog("Buddy")
my_dog.bark()
my_dog = Dog("Buddy")
my_dog.bark()
my_dog = Dog("Buddy")
my_dog.bark()
my_dog = Dog("Buddy")
my_dog.bark()
my_dog = Dog("Buddy")
my_dog.bark()
# Out:
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
# Buddy says Woof!
